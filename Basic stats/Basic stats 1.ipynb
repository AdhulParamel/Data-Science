# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('sales_data_with_discounts.csv')

# %%
df.shape
# Out:
# (450, 13)

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
print(df.dtypes)
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
c=df.select_dtypes(['int','float']).columns
c
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
df.Volume.agg(['mean','median',])
# Out:
# mean      5.066667
# median    4.000000
# Name: Volume, dtype: float64

# %%
df['Avg Price'].agg(['mean','median',])
# Out:
# mean      10453.433333
# median     1450.000000
# Name: Avg Price, dtype: float64

# %%
df['Total Sales Value'].agg(['mean','median',])
# Out:
# mean      33812.835556
# median     5700.000000
# Name: Total Sales Value, dtype: float64

# %%
df['Discount Rate (%)'].agg(['mean','median',])
# Out:
# mean      15.155242
# median    16.577766
# Name: Discount Rate (%), dtype: float64

# %%
df['Discount Amount'].agg(['mean','median',])
# Out:
# mean      3346.499424
# median     988.933733
# Name: Discount Amount, dtype: float64

# %%
df['Net Sales Value'].agg(['mean','median',])
# Out:
# mean      30466.336131
# median     4677.788059
# Name: Net Sales Value, dtype: float64

# %%
mean=df[c].mean()
mean
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
median=df[c].median()
median
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
mode=df[c].mode()
mode
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0       3.0      400.0            24300.0           5.007822        69.177942
# 1       NaN      450.0                NaN           5.055218        73.025199
# 2       NaN      500.0                NaN           5.059801        93.649161
# 3       NaN     1300.0                NaN           5.072124        94.682735
# 4       NaN     8100.0                NaN           5.084108       102.705757
# ..      ...        ...                ...                ...              ...
# 445     NaN        NaN                NaN          19.940610     17900.983733
# 446     NaN        NaN                NaN          19.965340     21153.498820
# 447     NaN        NaN                NaN          19.976879     21496.675367
# 448     NaN        NaN                NaN          19.982257     25328.224204
# 449     NaN        NaN                NaN          19.992407     25738.022194
#
#      Net Sales Value
# ...

# %%
df.Volume.value_counts()
# Out:
# Volume
# 3     110
# 2      76
# 4      61
# 6      38
# 5      38
# 7      32
# 1      27
# 12     10
# 11      9
# 9       9
# 8       8
# 10      7
# 15      6
# 14      5
# 13      4
# 29      2
# 24      2
# 22      2
# 25      1
# 31      1
# 16      1
# 17      1
# Name: count, dtype: int64

# %%
df['Discount Amount'].value_counts()
# Out:
# Discount Amount
# 21153.498820    1
# 5297.169083     1
# 3303.849511     1
# 12365.053308    1
# 4845.568296     1
#                ..
# 1881.585496     1
# 903.739433      1
# 1590.184282     1
# 1047.903783     1
# 475.332295      1
# Name: count, Length: 450, dtype: int64

# %%
df['Net Sales Value'].value_counts()
# Out:
# Net Sales Value
# 160346.501180    1
# 48802.830917     1
# 50796.150489     1
# 134934.946692    1
# 19454.431704     1
#                 ..
# 8518.414504      1
# 4296.260567      1
# 6805.815718      1
# 5452.096217      1
# 2624.667705      1
# Name: count, Length: 450, dtype: int64

# %%
df['Avg Price'].value_counts()
# Out:
# Avg Price
# 450      30
# 8100     30
# 1300     30
# 400      30
# 500      30
# 12100    15
# 1900     15
# 1600     15
# 2600     15
# 2099     15
# 900      15
# 1099     15
# 560      15
# 465      15
# 290      15
# 10100    15
# 390      15
# 300      15
# 60100    15
# 55100    15
# 54100    15
# 49100    15
# 20100    15
# 16100    15
# 3100     15
# Name: count, dtype: int64

# %%
std=df[c].std()
std
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
df[c].agg(['mean','median','std'])
# Out:
#           Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# mean    5.066667  10453.433333       33812.835556          15.155242
# median  4.000000   1450.000000        5700.000000          16.577766
# std     4.231602  18079.904840       50535.074173           4.220602
#
#         Discount Amount  Net Sales Value
# mean        3346.499424     30466.336131
# median       988.933733      4677.788059
# std         4509.902963     46358.656624

# %%
df.hist()
plt.tight_layout()
plt.show()

# %%
sns.kdeplot(data=df,x='Volume',color='pink')
plt.show()

# %%
df.boxplot(figsize=(10,5))
plt.show()

# %%
df.isnull().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
def outlier_capping(df,column):
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)
    IQR=Q3-Q1
    lower_extreme=Q1-1.5*IQR
    upper_extreme=Q3+1.5*IQR
    df[column]=df[column].apply(lambda x: lower_extreme if x< lower_extreme else upper_extreme if x>upper_extreme else x)

for col in df.select_dtypes(['float','int']).columns:
    outlier_capping(df,col)

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C    10.5  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C    10.0  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C     7.0  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C     6.0  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C     3.0  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0    12100.0           128950.0          11.654820     12600.549611
# 1    10100.0           101000.0          11.560498     11676.102961
# 2    16100.0           112700.0           9.456886     10657.910157
# 3    20100.0           120600.0           7.740579      8364.074702
# 4     8100.0            24300.0          17.995663      4372.946230
#
#    Net Sales Value
# 0    116316.469161
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
df.boxplot()
plt.show()

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C    10.5  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C    10.0  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C     7.0  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C     6.0  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C     3.0  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0    12100.0           128950.0          11.654820     12600.549611
# 1    10100.0           101000.0          11.560498     11676.102961
# 2    16100.0           112700.0           9.456886     10657.910157
# 3    20100.0           120600.0           7.740579      8364.074702
# 4     8100.0            24300.0          17.995663      4372.946230
#
#    Net Sales Value
# 0    116316.469161
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
d=df.select_dtypes(['object']).columns
d
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
df['City'].value_counts()
# Out:
# City
# C    450
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='BU')
plt.show()

# %%
sns.countplot(data=df,x='Model',color='red',gap=0.7)
plt.show()

# %%
sns.countplot(data=df,x='Date')
plt.show()

# %%
sns.countplot(data=df,x='Day')
plt.show()

# %%
sns.countplot(data=df,x='SKU')
plt.show()

# %%
sns.countplot(data=df,x='City')
plt.show()

# %%
sns.countplot(data=df,x='Brand')
plt.show()

# %%
# Out:
#   Cell In[348], line 4
#     sns.countplot(data=df, x='BU',ax[0,1])
#                                          ^
# SyntaxError: positional argument follows keyword argument
