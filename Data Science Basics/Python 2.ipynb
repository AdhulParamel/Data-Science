# %% [markdown]
# # Section A

# %% [markdown]
# ## 1

# %%
list=[1,2,3,4,5]
list
# Out:
# [1, 2, 3, 4, 5]

# %%
list.append(6)
list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list.extend([7,8])
list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list.insert(0,0)
list
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
list.remove(2)
list
# Out:
# [0, 1, 3, 4, 5, 6, 7, 8]

# %%
list.pop()
list
# Out:
# [0, 1, 3, 4, 5, 6, 7]

# %%
list.clear()
list
# Out:
# []

# %%
list=[1,2,3,4,5,6,7,8,9,4]
list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 4]

# %%
list.index(5)
# Out:
# 4

# %%
list.count(4)
# Out:
# 2

# %%
list.sort()
list
# Out:
# [1, 2, 3, 4, 4, 5, 6, 7, 8, 9]

# %%
list.reverse()
list
# Out:
# [9, 8, 7, 6, 5, 4, 4, 3, 2, 1]

# %% [markdown]
# ## 2

# %%
tuple=("Aryan","Nevin","Anu")
tuple
# Out:
# ('Aryan', 'Nevin', 'Anu')

# %%
tuple[2]=("Sabu")
tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 tuple[2]=("Sabu")
#       2 tuple
#
# TypeError: 'tuple' object does not support item assignment

# %%
## It cannot be renamed Tuple cannot be modified.To modify tuple it have to be converted to list

# %% [markdown]
# ## 3

# %%
n={1,2,3,4,2,3,4,5,6,7}
n
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
## In a set duplicate elements are removed when printed because a set is always unique in elements

# %% [markdown]
# ## 4

# %%
dict={'name':{'Adhila','Lekshmi','Noora'},
       'age':{25,26,28},
       'city':{'Banglore','Chennai','Mumbai'}}
dict
# Out:
# {'name': {'Adhila', 'Lekshmi', 'Noora'},
#  'age': {25, 26, 28},
#  'city': {'Banglore', 'Chennai', 'Mumbai'}}

# %%
dict.update({'age':{22,20,27}})
dict
# Out:
# {'name': {'Adhila', 'Lekshmi', 'Noora'},
#  'age': {20, 22, 27},
#  'city': {'Banglore', 'Chennai', 'Mumbai'}}

# %%
dict['email']={'adhila@gmail.com','noora@gmail.com','lekshmi@gmail.com'}
dict
# Out:
# {'name': {'Adhila', 'Lekshmi', 'Noora'},
#  'age': {20, 22, 27},
#  'city': {'Banglore', 'Chennai', 'Mumbai'},
#  'email': {'adhila@gmail.com', 'lekshmi@gmail.com', 'noora@gmail.com'}}

# %% [markdown]
# ## 5

# %%
age=int(input("Enter age"))
if (age>=18):
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Enter age 15
# Not eligible to vote

# %% [markdown]
# ## 6

# %%
mark=int(input("Enter the mark"))
if (mark>=90):
    print("A")
elif(mark>=75):
    print("B")
elif(mark>=50):
    print("C")
else:
    print("Fail")
# Out:
# Enter the mark 24
# Fail

# %% [markdown]
# ## 7

# %%
n=int(input())
if(n>0):
    print("positive")
    if(n%2==0):
        print("even")
elif(n==0):
    print("Zero")
else:
    print("Negative")
# Out:
#  -9
# Negative

# %% [markdown]
# # Section B

# %% [markdown]
# ## 8

# %%
import numpy as np
num=np.array(5)
num
# Out:
# array(5)

# %%
num=np.array([1,2,3,4,5])
num
# Out:
# array([1, 2, 3, 4, 5])

# %%
num=np.array([[10,20,30],[40,50,60]])
num
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %% [markdown]
# ## 9

# %%
a=np.array(np.random.randint(0,100,16).reshape(4,4))
a
# Out:
# array([[12, 91, 15, 76],
#        [41, 76, 35,  3],
#        [79, 25, 69, 69],
#        [60, 16, 21, 93]])

# %% [markdown]
# ## 10

# %%
import numpy as np
import pandas as pd
num=np.array(np.random.randint(0,50,9).reshape(3,3))
num
# Out:
# array([[ 1, 30, 20],
#        [28, 13,  0],
#        [41,  3, 37]])

# %%
df=pd.DataFrame(num,columns=('A','B','C'))
df
# Out:
#     A   B   C
# 0   1  30  20
# 1  28  13   0
# 2  41   3  37

# %% [markdown]
# # Section C

# %% [markdown]
# ## 11

# %%
dict1={'name':['Adhila','Noora','Adhila','Shanavas','Nevin','Anu','Lekshmi','Aryan','Akbar','Gizele'],
       'Age':[20,21,20,32,23,25,33,25,27,48],
       'City':['Banglore','Chennai','Banglore','Pune','Thrissur','Kolkata','Hyderabad','Goa','Kolkata','Rajasthan'],
       'Salary':[20000,np.nan,20000,50000,34000,54000,23000,34000,43400,10000]}
print(dict1)
# Out:
# {'name': ['Adhila', 'Noora', 'Adhila', 'Shanavas', 'Nevin', 'Anu', 'Lekshmi', 'Aryan', 'Akbar', 'Gizele'], 'Age': [20, 21, 20, 32, 23, 25, 33, 25, 27, 48], 'City': ['Banglore', 'Chennai', 'Banglore', 'Pune', 'Thrissur', 'Kolkata', 'Hyderabad', 'Goa', 'Kolkata', 'Rajasthan'], 'Salary': [20000, nan, 20000, 50000, 34000, 54000, 23000, 34000, 43400, 10000]}

# %%
df1=pd.DataFrame(dict1)
df1
# Out:
#        name  Age       City   Salary
# 0    Adhila   20   Banglore  20000.0
# 1     Noora   21    Chennai      NaN
# 2    Adhila   20   Banglore  20000.0
# 3  Shanavas   32       Pune  50000.0
# 4     Nevin   23   Thrissur  34000.0
# 5       Anu   25    Kolkata  54000.0
# 6   Lekshmi   33  Hyderabad  23000.0
# 7     Aryan   25        Goa  34000.0
# 8     Akbar   27    Kolkata  43400.0
# 9    Gizele   48  Rajasthan  10000.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   City    10 non-null     object
#  3   Salary  9 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 452.0+ bytes

# %%
df1.describe()
# Out:
#              Age        Salary
# count  10.000000      9.000000
# mean   27.400000  32044.444444
# std     8.553102  14995.591945
# min    20.000000  10000.000000
# 25%    21.500000  20000.000000
# 50%    25.000000  34000.000000
# 75%    30.750000  43400.000000
# max    48.000000  54000.000000

# %%
df1.iloc[:,[1,2]]
# Out:
#    Age       City
# 0   20   Banglore
# 1   21    Chennai
# 2   20   Banglore
# 3   32       Pune
# 4   23   Thrissur
# 5   25    Kolkata
# 6   33  Hyderabad
# 7   25        Goa
# 8   27    Kolkata
# 9   48  Rajasthan

# %%
df1.drop(columns=['City'])
# Out:
#        name  Age   Salary
# 0    Adhila   20  20000.0
# 1     Noora   21      NaN
# 2    Adhila   20  20000.0
# 3  Shanavas   32  50000.0
# 4     Nevin   23  34000.0
# 5       Anu   25  54000.0
# 6   Lekshmi   33  23000.0
# 7     Aryan   25  34000.0
# 8     Akbar   27  43400.0
# 9    Gizele   48  10000.0

# %%
df1.isnull().sum()
# Out:
# name      0
# Age       0
# City      0
# Salary    1
# dtype: int64

# %%
df1['Salary'].fillna(df1['Salary'].mean())
# Out:
# 0    20000.000000
# 1    32044.444444
# 2    20000.000000
# 3    50000.000000
# 4    34000.000000
# 5    54000.000000
# 6    23000.000000
# 7    34000.000000
# 8    43400.000000
# 9    10000.000000
# Name: Salary, dtype: float64

# %%
df1.duplicated().sum()
# Out:
# 1

# %%
df1.drop_duplicates()
# Out:
#        name  Age       City   Salary
# 0    Adhila   20   Banglore  20000.0
# 1     Noora   21    Chennai      NaN
# 3  Shanavas   32       Pune  50000.0
# 4     Nevin   23   Thrissur  34000.0
# 5       Anu   25    Kolkata  54000.0
# 6   Lekshmi   33  Hyderabad  23000.0
# 7     Aryan   25        Goa  34000.0
# 8     Akbar   27    Kolkata  43400.0
# 9    Gizele   48  Rajasthan  10000.0
